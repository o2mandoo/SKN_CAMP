# %% [markdown]
# <a href="https://colab.research.google.com/github/sunsnu/SKN_CAMP/blob/main/250701_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' 1. Module Import '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.6.0+cu124  Device: cpu

# %%
DEVICE
# Out:
# device(type='cpu')

# %%
BATCH_SIZE = 32
EPOCHS = 20

# %%
train_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                  train = True,
                                  download = True,
                                  transform = transforms.ToTensor())

test_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                train = False,
                                transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                            batch_size = BATCH_SIZE,
                                            shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.5MB/s]

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 8, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = 3, padding = 1)
        self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.fc1 = nn.Linear(8 * 8 * 16, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)

        x = x.view(-1, 8 * 8 * 16)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        x = F.log_softmax(x)
        return x

# %%
model = CNN().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.CrossEntropyLoss()

# %%
def train(model, train_loader, optimizer, log_interval):
    global output, label
    model.train()
    correct = 0
    train_loss = 0
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

        _, prediction = torch.max(output, dim=1 )
        # 정답을 맞춘 갯수
        # acc += sum(idx == label)
        correct += prediction.eq(label.view_as(prediction)).sum().item()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))

    train_loss /= (len(train_loader.dataset) / BATCH_SIZE)
    train_accuracy = 100. * correct / len(train_loader.dataset)

    return train_loss, train_accuracy

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
loss_hist_train     = [0] * EPOCHS
accuracy_hist_train = [0] * EPOCHS
loss_hist_valid     = [0] * EPOCHS
accuracy_hist_valid = [0] * EPOCHS
for epoch in range(1, EPOCHS + 1):
    loss_, acc_ = train(model, train_loader, optimizer, log_interval = 200)
    loss_hist_train[epoch-1] = loss_
    accuracy_hist_train[epoch-1] = acc_
    test_loss, test_accuracy = evaluate(model, test_loader)
    loss_hist_valid[epoch-1] = test_loss
    accuracy_hist_valid[epoch-1] = test_accuracy
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# /tmp/ipython-input-8-1875207390.py:25: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.log_softmax(x)
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.271193
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 2.043186
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.815066
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 1.600159
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.695589
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 1.604652
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 1.700428
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.560278
#
# [EPOCH: 1], 	Test Loss: 1.5508, 	Test Accuracy: 43.66 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 1.474631
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.397208
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.550168
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.508736
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.743586
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.384827
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 1.487447
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.589175
#
# [EPOCH: 2], 	Test Loss: 1.3353, 	Test Accuracy: 52.61 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 1.212130
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 1.312087
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 1.093618
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 1.597200
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 1.577471
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 1.430138
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.337231
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 1.210245
#
# [EPOCH: 3], 	Test Loss: 1.2517, 	Test Accuracy: 54.75 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 1.292069
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 1.563578
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 1.402689
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 0.956033
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 1.152978
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 0.791704
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 0.915652
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 1.174181
#
# [EPOCH: 4], 	Test Loss: 1.1697, 	Test Accuracy: 58.60 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 0.952853
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 1.441538
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 0.947145
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 1.405455
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 1.176204
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 1.273853
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 1.166327
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 0.948892
#
# [EPOCH: 5], 	Test Loss: 1.1669, 	Test Accuracy: 58.36 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 0.869228
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 1.333402
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 1.048876
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 1.014611
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 1.124065
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 0.921516
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 1.184645
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 0.856872
#
# [EPOCH: 6], 	Test Loss: 1.1263, 	Test Accuracy: 60.93 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 0.971347
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 1.112627
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 1.138494
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 1.359220
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 0.827612
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 0.948724
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 1.195373
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 0.620372
#
# [EPOCH: 7], 	Test Loss: 1.0810, 	Test Accuracy: 61.64 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 1.230831
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 0.804377
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 0.892046
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 0.917879
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 1.196830
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 0.881468
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 1.008840
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 1.228462
#
# [EPOCH: 8], 	Test Loss: 1.0647, 	Test Accuracy: 62.75 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 0.911352
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 1.144580
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 0.901739
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 0.676442
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 0.738031
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 0.957064
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 0.766035
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 0.914859
#
# [EPOCH: 9], 	Test Loss: 1.1106, 	Test Accuracy: 60.83 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 1.107502
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 0.644736
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 0.858762
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 0.786320
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 0.717649
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 0.746523
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 0.742273
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 0.927032
#
# [EPOCH: 10], 	Test Loss: 1.0505, 	Test Accuracy: 63.26 %
#
# Train Epoch: 11 [0/50000 (0%)]	Train Loss: 0.901561
# Train Epoch: 11 [6400/50000 (13%)]	Train Loss: 0.931697
# Train Epoch: 11 [12800/50000 (26%)]	Train Loss: 0.941219
# Train Epoch: 11 [19200/50000 (38%)]	Train Loss: 0.855105
# Train Epoch: 11 [25600/50000 (51%)]	Train Loss: 0.762258
# Train Epoch: 11 [32000/50000 (64%)]	Train Loss: 0.939199
# Train Epoch: 11 [38400/50000 (77%)]	Train Loss: 0.946701
# Train Epoch: 11 [44800/50000 (90%)]	Train Loss: 0.616146
#
# [EPOCH: 11], 	Test Loss: 1.0481, 	Test Accuracy: 63.26 %
#
# Train Epoch: 12 [0/50000 (0%)]	Train Loss: 0.841579
# Train Epoch: 12 [6400/50000 (13%)]	Train Loss: 0.833726
# Train Epoch: 12 [12800/50000 (26%)]	Train Loss: 1.166043
# Train Epoch: 12 [19200/50000 (38%)]	Train Loss: 0.718754
# Train Epoch: 12 [25600/50000 (51%)]	Train Loss: 0.635530
# Train Epoch: 12 [32000/50000 (64%)]	Train Loss: 0.816912
# Train Epoch: 12 [38400/50000 (77%)]	Train Loss: 0.919671
# Train Epoch: 12 [44800/50000 (90%)]	Train Loss: 0.999810
#
# [EPOCH: 12], 	Test Loss: 1.0277, 	Test Accuracy: 64.29 %
#
# Train Epoch: 13 [0/50000 (0%)]	Train Loss: 0.909153
# Train Epoch: 13 [6400/50000 (13%)]	Train Loss: 0.791725
# Train Epoch: 13 [12800/50000 (26%)]	Train Loss: 0.880509
# Train Epoch: 13 [19200/50000 (38%)]	Train Loss: 0.837229
# Train Epoch: 13 [25600/50000 (51%)]	Train Loss: 0.707832
# Train Epoch: 13 [32000/50000 (64%)]	Train Loss: 0.909709
# Train Epoch: 13 [38400/50000 (77%)]	Train Loss: 0.482248
# Train Epoch: 13 [44800/50000 (90%)]	Train Loss: 0.534937
#
# [EPOCH: 13], 	Test Loss: 1.0811, 	Test Accuracy: 63.02 %
#
# Train Epoch: 14 [0/50000 (0%)]	Train Loss: 0.739339
# Train Epoch: 14 [6400/50000 (13%)]	Train Loss: 0.746039
# Train Epoch: 14 [12800/50000 (26%)]	Train Loss: 0.732895
# Train Epoch: 14 [19200/50000 (38%)]	Train Loss: 0.900367
# Train Epoch: 14 [25600/50000 (51%)]	Train Loss: 0.848631
# Train Epoch: 14 [32000/50000 (64%)]	Train Loss: 0.979117
# Train Epoch: 14 [38400/50000 (77%)]	Train Loss: 0.646367
# Train Epoch: 14 [44800/50000 (90%)]	Train Loss: 0.891650
#
# [EPOCH: 14], 	Test Loss: 1.0400, 	Test Accuracy: 63.79 %
#
# Train Epoch: 15 [0/50000 (0%)]	Train Loss: 0.957493
# Train Epoch: 15 [6400/50000 (13%)]	Train Loss: 0.923978
# Train Epoch: 15 [12800/50000 (26%)]	Train Loss: 0.884635
# Train Epoch: 15 [19200/50000 (38%)]	Train Loss: 1.178038
# Train Epoch: 15 [25600/50000 (51%)]	Train Loss: 0.721267
# Train Epoch: 15 [32000/50000 (64%)]	Train Loss: 0.833736
# Train Epoch: 15 [38400/50000 (77%)]	Train Loss: 0.835294
# Train Epoch: 15 [44800/50000 (90%)]	Train Loss: 0.735384
#
# [EPOCH: 15], 	Test Loss: 1.0310, 	Test Accuracy: 64.49 %
#
# Train Epoch: 16 [0/50000 (0%)]	Train Loss: 0.768434
# Train Epoch: 16 [6400/50000 (13%)]	Train Loss: 1.094125
# Train Epoch: 16 [12800/50000 (26%)]	Train Loss: 1.127168
# Train Epoch: 16 [19200/50000 (38%)]	Train Loss: 1.301646
# Train Epoch: 16 [25600/50000 (51%)]	Train Loss: 0.827404
# Train Epoch: 16 [32000/50000 (64%)]	Train Loss: 0.880857
# Train Epoch: 16 [38400/50000 (77%)]	Train Loss: 0.803471
# Train Epoch: 16 [44800/50000 (90%)]	Train Loss: 1.210857
#
# [EPOCH: 16], 	Test Loss: 1.0125, 	Test Accuracy: 64.95 %
#
# Train Epoch: 17 [0/50000 (0%)]	Train Loss: 0.999792
# Train Epoch: 17 [6400/50000 (13%)]	Train Loss: 1.118436
# Train Epoch: 17 [12800/50000 (26%)]	Train Loss: 0.732865
# Train Epoch: 17 [19200/50000 (38%)]	Train Loss: 0.924904
# Train Epoch: 17 [25600/50000 (51%)]	Train Loss: 1.249588
# Train Epoch: 17 [32000/50000 (64%)]	Train Loss: 0.937213
# Train Epoch: 17 [38400/50000 (77%)]	Train Loss: 0.972476
# Train Epoch: 17 [44800/50000 (90%)]	Train Loss: 0.530848
#
# [EPOCH: 17], 	Test Loss: 1.0161, 	Test Accuracy: 64.71 %
#
# Train Epoch: 18 [0/50000 (0%)]	Train Loss: 0.933877
# Train Epoch: 18 [6400/50000 (13%)]	Train Loss: 0.685281
# Train Epoch: 18 [12800/50000 (26%)]	Train Loss: 0.542634
# Train Epoch: 18 [19200/50000 (38%)]	Train Loss: 0.854484
# Train Epoch: 18 [25600/50000 (51%)]	Train Loss: 1.118276
# Train Epoch: 18 [32000/50000 (64%)]	Train Loss: 0.922623
# Train Epoch: 18 [38400/50000 (77%)]	Train Loss: 1.107250
# Train Epoch: 18 [44800/50000 (90%)]	Train Loss: 1.215000
#
# [EPOCH: 18], 	Test Loss: 1.0296, 	Test Accuracy: 64.20 %
#
# Train Epoch: 19 [0/50000 (0%)]	Train Loss: 0.665784
# Train Epoch: 19 [6400/50000 (13%)]	Train Loss: 0.804617
# Train Epoch: 19 [12800/50000 (26%)]	Train Loss: 0.762840
# Train Epoch: 19 [19200/50000 (38%)]	Train Loss: 1.177274
# Train Epoch: 19 [25600/50000 (51%)]	Train Loss: 1.135629
# Train Epoch: 19 [32000/50000 (64%)]	Train Loss: 1.135602
# Train Epoch: 19 [38400/50000 (77%)]	Train Loss: 0.934021
# Train Epoch: 19 [44800/50000 (90%)]	Train Loss: 0.836607
#
# [EPOCH: 19], 	Test Loss: 1.0080, 	Test Accuracy: 65.57 %
#
# Train Epoch: 20 [0/50000 (0%)]	Train Loss: 0.581355
# Train Epoch: 20 [6400/50000 (13%)]	Train Loss: 0.926282
# Train Epoch: 20 [12800/50000 (26%)]	Train Loss: 0.585551
# Train Epoch: 20 [19200/50000 (38%)]	Train Loss: 1.059379
# Train Epoch: 20 [25600/50000 (51%)]	Train Loss: 0.838988
# Train Epoch: 20 [32000/50000 (64%)]	Train Loss: 0.681844
# Train Epoch: 20 [38400/50000 (77%)]	Train Loss: 1.073076
# Train Epoch: 20 [44800/50000 (90%)]	Train Loss: 0.743135
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-12-2711708183.py in <cell line: 0>()
#       5 for epoch in range(1, EPOCHS + 1):
#       6     loss_, acc_ = train(model, train_loader, optimizer, log_interval = 200)
# ----> 7     loss_hist_train[epoch] = loss_
#       8     accuracy_hist_train[epoch] = acc_
#       9     test_loss, test_accuracy = evaluate(model, test_loader)
#
# IndexError: list assignment index out of range

# %%
x_arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-12-918081632.py in <cell line: 0>()
# ----> 1 x_arr
#
# NameError: name 'x_arr' is not defined

# %%
x_arr = np.arange(len(loss_hist_train[1:])) + 1
#accuracy_hist_train
#loss_hist_valid [1:]
#accuracy_hist_valid
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr,loss_hist_train[1:], '-o', label='Train loass' )
ax.plot(x_arr,loss_hist_valid[1:], '-o', label='Valid loass' )
ax.legend()

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr,accuracy_hist_train[1:], '-o', label='Train accuracy' )
ax.plot(x_arr,accuracy_hist_valid[1:], '-o', label='Valid accuracy' )
ax.legend()
plt.show()

# %%
class test:
  def __init(self):
    pass
  def __str__(self):
    return "hi"
  def __call__(self):
    print("call 호출")

# %%
t= test()

# %%
print(t)
# Out:
# hi

# %%
t()
# Out:
# call 호출

# %%
class test:
  def __init(self):
    pass
  def __str__(self):
    return "hi"


  def __call__(self):
    print("call 호출")

# %%
class early_stopping:
  def __init__(self, patience, verbose, delta, path='checkpoint.pt'):
    self.patience = patience
    self.verbose = verbose
    self.delta = delta
    self.count = 0
    self.best_score = None
    self.early_stop = False
    self.val_loss_min = np.inf
    self.path = path


  def __call__(self, val_loss, model):
    score = -val_loss


    if self.best_score is None:
      self.best_score = score
      self.save_checkpoint(val_loss, model)
    elif score < self.best_score + self.delta:
      self.count += 1
      if self.verbose:
        print(f"Early Stopping counter: {self.count} out of {self.patience}")


      if self.count >= self.patience:
        self.early_stop = True
    else:
      self.best_score = score
      self.save_checkpoint(val_loss, model)
      self.count =0


  def save_checkpoint(self, val_loss, model):
    if self.verbose:
      print(f"Validation loss decreased ({self.val_loss_min:.6f}) --> {val_loss:.6f}. saving model..")
    torch.save(model.state_dict(), self.path)
    self.val_loss_min = val_loss

# %%
loss_hist_train     = [0] * EPOCHS
accuracy_hist_train = [0] * EPOCHS
loss_hist_valid     = [0] * EPOCHS
accuracy_hist_valid = [0] * EPOCHS
early_stopping = early_stopping(patience = 3, verbose = True, delta = 0)


for epoch in range(1, EPOCHS + 1):
    loss_, acc_ = train(model, train_loader, optimizer, log_interval = 200)
    loss_hist_train[epoch-1] = loss_
    accuracy_hist_train[epoch-1] = acc_
    test_loss, test_accuracy = evaluate(model, test_loader)
    loss_hist_valid[epoch-1] = test_loss
    accuracy_hist_valid[epoch-1] = test_accuracy

    early_stopping(test_loss, model)
    if early_stopping.early_stop:
      print("Early stopping")
      break


    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# /tmp/ipython-input-8-1875207390.py:25: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.log_softmax(x)
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 2.313497
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 1.858926
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 1.854830
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 1.668973
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.527837
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 1.797524
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 1.662369
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.767092
# Validation loss decreased (inf) --> 1.462961. saving model..
#
# [EPOCH: 1], 	Test Loss: 1.4630, 	Test Accuracy: 46.94 %
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 1.334422
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.478739
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.363373
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.535915
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.379045
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.575674
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 1.438883
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.212475
# Validation loss decreased (1.462961) --> 1.343377. saving model..
#
# [EPOCH: 2], 	Test Loss: 1.3434, 	Test Accuracy: 51.75 %
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 1.626879
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 1.053946
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 1.205161
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 1.443281
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 1.215537
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 1.224742
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.096475
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 1.066056
# Validation loss decreased (1.343377) --> 1.255061. saving model..
#
# [EPOCH: 3], 	Test Loss: 1.2551, 	Test Accuracy: 54.71 %
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 1.149859
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 1.191912
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 1.125975
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 1.165655
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 1.256023
# Train Epoch: 4 [32000/50000 (64%)]	Train Loss: 1.223835
# Train Epoch: 4 [38400/50000 (77%)]	Train Loss: 0.895676
# Train Epoch: 4 [44800/50000 (90%)]	Train Loss: 1.200393
# Validation loss decreased (1.255061) --> 1.205637. saving model..
#
# [EPOCH: 4], 	Test Loss: 1.2056, 	Test Accuracy: 56.54 %
#
# Train Epoch: 5 [0/50000 (0%)]	Train Loss: 1.240477
# Train Epoch: 5 [6400/50000 (13%)]	Train Loss: 1.427081
# Train Epoch: 5 [12800/50000 (26%)]	Train Loss: 1.144733
# Train Epoch: 5 [19200/50000 (38%)]	Train Loss: 0.882510
# Train Epoch: 5 [25600/50000 (51%)]	Train Loss: 0.999419
# Train Epoch: 5 [32000/50000 (64%)]	Train Loss: 1.289161
# Train Epoch: 5 [38400/50000 (77%)]	Train Loss: 0.959695
# Train Epoch: 5 [44800/50000 (90%)]	Train Loss: 0.853015
# Validation loss decreased (1.205637) --> 1.131844. saving model..
#
# [EPOCH: 5], 	Test Loss: 1.1318, 	Test Accuracy: 60.00 %
#
# Train Epoch: 6 [0/50000 (0%)]	Train Loss: 0.915271
# Train Epoch: 6 [6400/50000 (13%)]	Train Loss: 1.177722
# Train Epoch: 6 [12800/50000 (26%)]	Train Loss: 0.876474
# Train Epoch: 6 [19200/50000 (38%)]	Train Loss: 0.950025
# Train Epoch: 6 [25600/50000 (51%)]	Train Loss: 1.137370
# Train Epoch: 6 [32000/50000 (64%)]	Train Loss: 1.058534
# Train Epoch: 6 [38400/50000 (77%)]	Train Loss: 0.813059
# Train Epoch: 6 [44800/50000 (90%)]	Train Loss: 1.136218
# Validation loss decreased (1.131844) --> 1.105794. saving model..
#
# [EPOCH: 6], 	Test Loss: 1.1058, 	Test Accuracy: 61.26 %
#
# Train Epoch: 7 [0/50000 (0%)]	Train Loss: 0.996566
# Train Epoch: 7 [6400/50000 (13%)]	Train Loss: 0.964270
# Train Epoch: 7 [12800/50000 (26%)]	Train Loss: 0.954399
# Train Epoch: 7 [19200/50000 (38%)]	Train Loss: 0.963671
# Train Epoch: 7 [25600/50000 (51%)]	Train Loss: 0.899425
# Train Epoch: 7 [32000/50000 (64%)]	Train Loss: 1.037834
# Train Epoch: 7 [38400/50000 (77%)]	Train Loss: 1.458780
# Train Epoch: 7 [44800/50000 (90%)]	Train Loss: 0.959766
# Validation loss decreased (1.105794) --> 1.070767. saving model..
#
# [EPOCH: 7], 	Test Loss: 1.0708, 	Test Accuracy: 62.41 %
#
# Train Epoch: 8 [0/50000 (0%)]	Train Loss: 0.897314
# Train Epoch: 8 [6400/50000 (13%)]	Train Loss: 0.773303
# Train Epoch: 8 [12800/50000 (26%)]	Train Loss: 0.694917
# Train Epoch: 8 [19200/50000 (38%)]	Train Loss: 0.846295
# Train Epoch: 8 [25600/50000 (51%)]	Train Loss: 0.898036
# Train Epoch: 8 [32000/50000 (64%)]	Train Loss: 1.087608
# Train Epoch: 8 [38400/50000 (77%)]	Train Loss: 0.647333
# Train Epoch: 8 [44800/50000 (90%)]	Train Loss: 0.902385
# Early Stopping counter: 1 out of 3
#
# [EPOCH: 8], 	Test Loss: 1.0737, 	Test Accuracy: 63.15 %
#
# Train Epoch: 9 [0/50000 (0%)]	Train Loss: 1.037475
# Train Epoch: 9 [6400/50000 (13%)]	Train Loss: 0.831338
# Train Epoch: 9 [12800/50000 (26%)]	Train Loss: 0.825649
# Train Epoch: 9 [19200/50000 (38%)]	Train Loss: 0.779502
# Train Epoch: 9 [25600/50000 (51%)]	Train Loss: 1.059597
# Train Epoch: 9 [32000/50000 (64%)]	Train Loss: 1.009545
# Train Epoch: 9 [38400/50000 (77%)]	Train Loss: 0.911915
# Train Epoch: 9 [44800/50000 (90%)]	Train Loss: 0.948861
# Validation loss decreased (1.070767) --> 1.052727. saving model..
#
# [EPOCH: 9], 	Test Loss: 1.0527, 	Test Accuracy: 63.24 %
#
# Train Epoch: 10 [0/50000 (0%)]	Train Loss: 0.781644
# Train Epoch: 10 [6400/50000 (13%)]	Train Loss: 0.801329
# Train Epoch: 10 [12800/50000 (26%)]	Train Loss: 0.794901
# Train Epoch: 10 [19200/50000 (38%)]	Train Loss: 0.851721
# Train Epoch: 10 [25600/50000 (51%)]	Train Loss: 1.617103
# Train Epoch: 10 [32000/50000 (64%)]	Train Loss: 0.993362
# Train Epoch: 10 [38400/50000 (77%)]	Train Loss: 0.606728
# Train Epoch: 10 [44800/50000 (90%)]	Train Loss: 1.147930
# Validation loss decreased (1.052727) --> 1.037309. saving model..
#
# [EPOCH: 10], 	Test Loss: 1.0373, 	Test Accuracy: 63.49 %
#
# Train Epoch: 11 [0/50000 (0%)]	Train Loss: 0.861401
# Train Epoch: 11 [6400/50000 (13%)]	Train Loss: 0.947388
# Train Epoch: 11 [12800/50000 (26%)]	Train Loss: 0.758928
# Train Epoch: 11 [19200/50000 (38%)]	Train Loss: 0.844919
# Train Epoch: 11 [25600/50000 (51%)]	Train Loss: 0.701143
# Train Epoch: 11 [32000/50000 (64%)]	Train Loss: 0.836371
# Train Epoch: 11 [38400/50000 (77%)]	Train Loss: 1.272287
# Train Epoch: 11 [44800/50000 (90%)]	Train Loss: 1.327769
# Validation loss decreased (1.037309) --> 1.023374. saving model..
#
# [EPOCH: 11], 	Test Loss: 1.0234, 	Test Accuracy: 64.44 %
#
# Train Epoch: 12 [0/50000 (0%)]	Train Loss: 1.101133
# Train Epoch: 12 [6400/50000 (13%)]	Train Loss: 0.801565
# Train Epoch: 12 [12800/50000 (26%)]	Train Loss: 1.038444
# Train Epoch: 12 [19200/50000 (38%)]	Train Loss: 0.784200
# Train Epoch: 12 [25600/50000 (51%)]	Train Loss: 1.005371
# Train Epoch: 12 [32000/50000 (64%)]	Train Loss: 1.060410
# Train Epoch: 12 [38400/50000 (77%)]	Train Loss: 0.727713
# Train Epoch: 12 [44800/50000 (90%)]	Train Loss: 0.905634
# Early Stopping counter: 1 out of 3
#
# [EPOCH: 12], 	Test Loss: 1.0338, 	Test Accuracy: 63.91 %
#
# Train Epoch: 13 [0/50000 (0%)]	Train Loss: 0.888435
# Train Epoch: 13 [6400/50000 (13%)]	Train Loss: 1.004336
# Train Epoch: 13 [12800/50000 (26%)]	Train Loss: 1.187538
# Train Epoch: 13 [19200/50000 (38%)]	Train Loss: 1.060350
# Train Epoch: 13 [25600/50000 (51%)]	Train Loss: 0.884820
# Train Epoch: 13 [32000/50000 (64%)]	Train Loss: 1.237533
# Train Epoch: 13 [38400/50000 (77%)]	Train Loss: 0.915090
# Train Epoch: 13 [44800/50000 (90%)]	Train Loss: 0.726128
# Validation loss decreased (1.023374) --> 1.010788. saving model..
#
# [EPOCH: 13], 	Test Loss: 1.0108, 	Test Accuracy: 65.02 %
#
# Train Epoch: 14 [0/50000 (0%)]	Train Loss: 0.997527
# Train Epoch: 14 [6400/50000 (13%)]	Train Loss: 0.754544
# Train Epoch: 14 [12800/50000 (26%)]	Train Loss: 0.922212
# Train Epoch: 14 [19200/50000 (38%)]	Train Loss: 0.687387
# Train Epoch: 14 [25600/50000 (51%)]	Train Loss: 0.898193
# Train Epoch: 14 [32000/50000 (64%)]	Train Loss: 0.816878
# Train Epoch: 14 [38400/50000 (77%)]	Train Loss: 0.654595
# Train Epoch: 14 [44800/50000 (90%)]	Train Loss: 0.757478
# Validation loss decreased (1.010788) --> 1.003925. saving model..
#
# [EPOCH: 14], 	Test Loss: 1.0039, 	Test Accuracy: 64.90 %
#
# Train Epoch: 15 [0/50000 (0%)]	Train Loss: 0.818653
# Train Epoch: 15 [6400/50000 (13%)]	Train Loss: 0.786536
# Train Epoch: 15 [12800/50000 (26%)]	Train Loss: 0.829963
# Train Epoch: 15 [19200/50000 (38%)]	Train Loss: 0.725040
# Train Epoch: 15 [25600/50000 (51%)]	Train Loss: 0.648018
# Train Epoch: 15 [32000/50000 (64%)]	Train Loss: 0.831549
# Train Epoch: 15 [38400/50000 (77%)]	Train Loss: 0.786456
# Train Epoch: 15 [44800/50000 (90%)]	Train Loss: 0.884518
# Early Stopping counter: 1 out of 3
#
# [EPOCH: 15], 	Test Loss: 1.0356, 	Test Accuracy: 63.85 %
#
# Train Epoch: 16 [0/50000 (0%)]	Train Loss: 0.705415
# Train Epoch: 16 [6400/50000 (13%)]	Train Loss: 0.717293
# Train Epoch: 16 [12800/50000 (26%)]	Train Loss: 0.799800
# Train Epoch: 16 [19200/50000 (38%)]	Train Loss: 0.982660
# Train Epoch: 16 [25600/50000 (51%)]	Train Loss: 1.153740
# Train Epoch: 16 [32000/50000 (64%)]	Train Loss: 0.687343
# Train Epoch: 16 [38400/50000 (77%)]	Train Loss: 0.862748
# Train Epoch: 16 [44800/50000 (90%)]	Train Loss: 1.100092
# Early Stopping counter: 2 out of 3
#
# [EPOCH: 16], 	Test Loss: 1.0097, 	Test Accuracy: 65.10 %
#
# Train Epoch: 17 [0/50000 (0%)]	Train Loss: 0.759270
# Train Epoch: 17 [6400/50000 (13%)]	Train Loss: 0.775587
# Train Epoch: 17 [12800/50000 (26%)]	Train Loss: 0.881042
# Train Epoch: 17 [19200/50000 (38%)]	Train Loss: 0.894132
# Train Epoch: 17 [25600/50000 (51%)]	Train Loss: 0.689878
# Train Epoch: 17 [32000/50000 (64%)]	Train Loss: 0.544182
# Train Epoch: 17 [38400/50000 (77%)]	Train Loss: 1.364470
# Train Epoch: 17 [44800/50000 (90%)]	Train Loss: 0.965293
# Early Stopping counter: 3 out of 3
# Early stopping
