# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pytorch-transformer/datasets/airport.mp4
# /kaggle/input/pytorch-transformer/datasets/binary.csv
# /kaggle/input/pytorch-transformer/datasets/woman.mp4
# /kaggle/input/pytorch-transformer/datasets/perceptron.csv
# /kaggle/input/pytorch-transformer/datasets/imagenet_classes.txt
# /kaggle/input/pytorch-transformer/datasets/non_linear.csv
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4329.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4223.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4253.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4190.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4354.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4136.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4226.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4214.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4888.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4170.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4323.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4262.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4788.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4657.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4387.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4255.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4607.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4203.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4970.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4520.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4151.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4822.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4008.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4318.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4089.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4729.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4372.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4314.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4499.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4250.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4321.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4272.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4651.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4989.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4042.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4945.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4437.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4831.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4300.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4270.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4310.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4359.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4713.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4810.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4655.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4991.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4345.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4176.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4322.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4833.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4133.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4352.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4851.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4341.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4852.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4539.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4837.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4413.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4847.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4109.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4403.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4191.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4930.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4734.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4179.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4132.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4357.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4400.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4686.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4781.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4718.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4305.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4117.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4951.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4855.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4581.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4022.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4070.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4904.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4461.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4147.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4043.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4925.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4621.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4672.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4998.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4332.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4482.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4801.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4077.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4495.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4692.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4956.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4637.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4181.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4055.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4693.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4283.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4205(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4611.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4148.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4164.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4496.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4804.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4094.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4472.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4902.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4762.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4308.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4291.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4193.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4626.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4232.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4681.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4366.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4938.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4338.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4265.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4846.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4818(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4627.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4107.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4994.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4777.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4360.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4793.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4886.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4913.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4078.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4580.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4350.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4486.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4358.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4731.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4288.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4187.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4738.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4739.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4096.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4399.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4216.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4444.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4135.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4785.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4868.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4750.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4827.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4727.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4228.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4273.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4634.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4615.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4235.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4877.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4493.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4408.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4095.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4209.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4279.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4392.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4725.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4889.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4915.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4875.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4608.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4242.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4159(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4146.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4501.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4536.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4351.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4215.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4157.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4030.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4595.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4774.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4526.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4210.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4119.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4252.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4711.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4034.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4006.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4936.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4650.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4775.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4619.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4906.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4248.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4118.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4519.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4158.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4628.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4218.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4227.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4478.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4633.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4172.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4044.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4066.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4491.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4267.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4220.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4124.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4668.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4948.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4616.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4012.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4642.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4004.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4275.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4825.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4987.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4747.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4141.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4596.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4743.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4417.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4293.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4090.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4824.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4577.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4589.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4189.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4538.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4704.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4770.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4707.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4397.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4617.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4173.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4582.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4661.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4230.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4258.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4849.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4660.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4587.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4384.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4390.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4780.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4224.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4058.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4249.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4549.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4653.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4375.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4471.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4304.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4830.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4800.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4114.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4139.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4051.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4268.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.5000.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4356.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4346.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4430.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4183.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4468.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4524.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4565.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4665.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4511.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4087.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4411.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4062.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4982.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4038.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4028.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4798.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4643.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4340.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4542.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4584.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4614.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4575.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4396.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4337.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4287.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4601.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4983.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4967.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4037.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4528.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4974.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4446.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4700.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4760.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4324.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4180.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4652.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4648.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4126.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4212.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4699.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4772.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4685.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4443.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4298.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4953.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4448.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4941.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4746.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4131.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4406.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4754.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4199.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4502.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4805.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4342.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4845.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4442.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4503.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4075.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4315.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4489.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4576.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4592.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4597.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4758.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4824(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4174.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4726.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4786.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4671.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4294.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4749.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4205.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4195.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4912.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4285.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4724.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4545.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4586.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4059.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4819.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4784.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4083.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4663.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4208.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4380.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4353.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4606.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4257.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4207.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4438.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4154.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4011.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4552.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4429.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4816.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4204.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4674.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4470.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4644.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4563(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4029.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4505.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4301.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4850.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4328.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4638.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4641.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4817.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4583.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4081.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4373.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4968.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4656.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4531.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4567.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4934.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4836.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4866.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4839.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4590.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4789.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4060.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4465.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4975.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4659.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4759.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4675.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4307.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4708.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4618.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4264.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4035.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4880.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4992.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4809.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4978.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4361.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4832.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4867.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4980.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4977.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4115.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4557.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4427.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4869.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4445.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4703.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4371.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4102.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4459.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4821.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4751.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4072.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4229.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4213.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4647.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4563.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4428.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4276.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4744.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4069.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4113.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4534.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4527.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4128.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4947.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4239.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4500.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4336.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4312.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4512.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4870.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4254.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4599.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4924.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4513.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4716.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4694.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4452.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4144.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4635.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4419.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4990.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4684.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4003.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4041.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4922.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4894.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4878.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4728.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4166.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4453.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4873.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4890.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4047.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4426.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4153.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4306.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4900.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4473.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4834.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4313.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4092.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4993.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4569.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4844.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4084.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4050.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4206.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4247.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4259.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4245.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4098.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4269.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4979.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4065.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4740.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4829.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4481.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4477.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4905.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4104.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4467.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4246.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4088.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4598.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4529.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4431.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4240.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4074.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4999.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4818.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4629.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4138.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4171(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4682.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4369.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4200.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4605.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4159.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4670.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4219.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4165(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4105.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4841.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4404.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4018.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4365.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4962.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4803.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4921.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4389.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4923.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4881.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4664.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4383.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4266.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4763.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4543.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4222.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4876.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4162.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4388.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4192.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4238.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4040.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4331.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4007.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4617(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4097.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4600.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4984.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4161.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4813.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4423.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4840.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4705.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4935.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4680.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4679.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4488.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4063.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4960.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4778.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4612.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4981.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4862.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4555.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4152.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4073.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4950.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4571.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4558.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4823.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4410.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4712.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4548.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4197.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4017.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4899.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4678.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4625.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4594.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4422.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4364.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4381.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4955.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4756.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4669.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4741.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4120.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4277.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4857.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4897.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4303.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4540.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4334.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4167.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4416.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4808.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4719.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4032.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4988.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4284.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4691.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4054.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4129.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4424.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4796.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4884.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4231.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4474.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4185.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4662.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4061.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4843.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4706.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4806.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4447.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4458.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4688.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4483.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4137.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4523.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4177.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4926.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4562.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4479.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4854.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4573.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4056.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4462.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4045.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4278.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4395.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4516.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4475.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4645.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4263.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4636.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4433.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4289.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4508.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4457.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4449.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4602.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4883.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4885.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4333.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4021.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4541.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4572.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4958.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4398.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4100.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4385.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4106.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4330.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4790.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4891.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4026.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4320.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4344.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4013.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4735.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4076.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4282.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4036.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4622.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4142.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4435.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4676.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4814.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4561.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4776.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4920.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4690.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4911.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4976.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4149.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4773.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4709.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4441.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4110.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4603.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4134.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4521.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4014.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4737.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4425.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4547.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4952.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4198.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4720.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4261.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4290.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4667.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4355.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4965.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4402.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4271.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4632.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4234.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4937.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4830(1).jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4812.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4742.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4835.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4241.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4281.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4165.jpg
# /kaggle/input/pytorch-transformer/datasets/pet/test/dog/dog.4101.jpg
# ...
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000578632.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000311961.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000548219.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000026803.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000173350.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000137028.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000291541.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000207093.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000227218.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000094566.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000362219.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000505945.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000178941.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000444343.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000246076.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000357322.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000516879.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000510383.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000381721.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000558127.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000233446.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000400728.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000428366.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000516408.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000310442.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000075768.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000099230.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000066960.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000212545.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000438628.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000209419.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000179441.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000051880.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000051403.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000471335.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000352196.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000101567.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000135275.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000186589.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000005105.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000053457.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000258523.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000075576.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000499302.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000015567.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000044347.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000045108.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000219567.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000301107.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000029370.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000245462.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000396094.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000466007.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000489940.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000090367.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000032677.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000187177.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000080213.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000463825.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000059652.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000535226.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000009041.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000397705.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000158798.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000052925.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000090366.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000283904.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000426283.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000161840.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000210060.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000209028.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000507301.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000163127.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000096288.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000568238.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000301735.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000017179.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000221523.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000477202.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000493862.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000037871.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000185550.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000033924.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000051272.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000284641.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000238291.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000543497.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000035489.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000133690.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000307993.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000321683.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000414078.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000012443.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000137188.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000504516.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000303550.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000433075.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000258773.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000318209.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000317480.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000194203.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000278435.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000519838.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000427965.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000268885.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000432120.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000264392.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000540452.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000290521.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000104494.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000492683.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000086215.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000370175.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000216417.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000180738.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000214671.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000319055.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000139781.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000223833.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000509497.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000084980.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000168847.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000120099.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000068878.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000495048.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000320974.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000357805.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000371890.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000179069.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000466789.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000411875.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000176697.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000108681.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000563403.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000163782.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000262396.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000490702.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000556758.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000486484.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000423742.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000443537.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000254540.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000273930.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000207509.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000339852.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000283210.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000178939.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000175729.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000007414.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000554377.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000430245.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000144862.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000354799.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000391139.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000547607.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000020438.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000485139.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000054643.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000408736.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000382717.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000522380.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000423337.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000097580.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000483447.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000014108.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000381555.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000194313.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000459598.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000094651.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000524245.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000417520.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000072810.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000016875.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000553547.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000250951.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000435922.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000124462.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000008131.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000026730.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000545475.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000218214.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000573759.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000317402.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000152103.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000078495.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000091304.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000427639.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000278184.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000493295.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000296056.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000405174.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000045367.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000388599.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000565797.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000253177.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000063950.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000543897.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000059501.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000289264.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000148458.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000300471.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000031745.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000149646.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000370210.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000002753.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000151585.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000320600.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000311531.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000162256.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000104421.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000006397.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000352549.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000500100.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000475928.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000489687.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000580255.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000256628.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000461156.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000042956.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000183571.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000385139.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000454154.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000196664.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000230220.jpg
# /kaggle/input/pytorch-transformer/datasets/coco/train/000000489743.jpg

# %%
import kagglehub

path = kagglehub.dataset_download("s076923/pytorch-transformer")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/pytorch-transformer

# %%
import os
import torch
from PIL import Image
from pycocotools.coco import COCO
from torch.utils.data import Dataset

# %%
root = "/kaggle/input/pytorch-transformer/datasets/coco/"
os.path.join(root,'anno','test')
# root 경로에 'anno'라는 폴더, 그 안에 'test'라는 폴더(또는 파일)를 이어 붙여서 하나의 전체 경로로 만들어줌
# Out:
# '/kaggle/input/pytorch-transformer/datasets/coco/anno/test'

# %%
class COCODataset(Dataset):
    def __init__(self):
        pass
    def __getitem__(self):
        pass
    def __len__(self):
        pass

# %%
train = True
directory = 'train' if train else 'val'
annotations = os.path.join(root, 'annotations', f"{directory}_annotations.json")

# %%
class COCODataset(Dataset):  # PyTorch의 Dataset 클래스를 상속받아 COCO 데이터셋을 다루는 클래스 정의
    def __init__(self, root, train, transform=None):
        super().__init__()  # 1. 부모 클래스(Dataset) 초기화 (필수)
        
        directory = "train" if train else "val"  # 2. 사용할 데이터셋 종류(train/val) 결정
        #    - train이 True면 'train', 아니면 'val'
        #    - 학습/검증 데이터셋을 쉽게 전환할 수 있도록 함
        
        annotations = os.path.join(root, "annotations", f"{directory}_annotations.json")  
        # 3. 어노테이션 파일 경로 생성
        #    - COCO 포맷의 라벨, 바운딩박스 등 정보가 저장된 json 파일의 경로
        
        self.coco = COCO(annotations)  # 4. COCO 어노테이션 파일을 읽어서 COCO 객체 생성
        #    - pycocotools의 COCO 클래스를 사용하여 어노테이션 정보를 쉽게 다룰 수 있게 함
        
        self.image_path = os.path.join(root, directory)  # 5. 실제 이미지가 저장된 폴더 경로 저장
        #    - 나중에 이미지 파일을 불러올 때 사용
        
        self.transform = transform  # 6. 이미지 전처리 함수(transform) 저장
        #    - 크기 조정, 텐서 변환, 데이터 증강 등에 사용 (없으면 None)
        
        self.categories = self.__get_categories()  # 7. 카테고리 정보를 딕셔너리로 저장
        #    - {0: 'background', 1: 'person', ...} 형태로 클래스 id와 이름 매핑
        
        self.data = self.__load_data()  # 8. 전체 이미지와 타깃 정보를 미리 불러와 저장
        #    - 메모리에 모든 데이터를 저장해두고, __getitem__에서 바로 꺼내쓸 수 있게 함

    def __get_categories(self):
        categories = {0 : 'background'}  # 1. 0번 클래스는 'background'로 지정 (COCO 기본 관례)
        for category in self.coco.cats.values():  # 2. COCO 어노테이션의 모든 카테고리 순회
            categories[category['id']] = category['name']  # 3. 카테고리 id와 이름을 딕셔너리에 추가
        return categories  # 4. 완성된 딕셔너리 반환

    def __load_data(self):
        data = []  # 1. 이미지와 타깃 정보를 저장할 리스트 생성
        for _id in self.coco.imgs:  # 2. COCO 데이터셋의 모든 이미지 id에 대해 반복
            file_name = self.coco.loadImgs(_id)[0]['file_name']  # 3. 이미지 파일명 가져오기
            image_path = os.path.join(self.image_path, file_name)  # 4. 전체 이미지 경로 생성
            image = Image.open(image_path).convert("RGB")  # 5. 이미지를 RGB로 열기

            boxes = []  # 6. 바운딩박스 좌표를 저장할 리스트
            labels = []  # 7. 객체 클래스 id를 저장할 리스트
            anns = self.coco.loadAnns(self.coco.getAnnIds(_id))  # 8. 해당 이미지의 모든 어노테이션(객체) 정보 가져오기

            for ann in anns:  # 9. 각 객체(어노테이션)별로 반복
                x, y, w, h = ann['bbox']  # 10. 바운딩박스 좌표(좌상단 x, y, 너비, 높이) 추출
                boxes.append([x, y, x+w, y+h])  # 11. [x1, y1, x2, y2] 형태로 변환해 저장
                labels.append(ann['category_id'])  # 12. 해당 객체의 클래스 id 저장

            # 13. PyTorch 학습에 맞게 타깃 딕셔너리 생성
            target = {
                'image_id' : torch.LongTensor([_id]),  # 이미지 id (텐서 형태)
                'boxes' : torch.FloatTensor(boxes),    # 바운딩박스 좌표 (텐서)
                'labels' : torch.LongTensor(labels)    # 클래스 id (텐서)
            }
            data.append([image, target])  # 14. 이미지와 타깃 정보를 한 쌍으로 리스트에 추가
        return data  # 15. 전체 데이터 반환

    def __getitem__(self, index):
        image, target = self.data[index]  # 1. 미리 저장해둔 data 리스트에서 index번째 샘플을 꺼냄
        if self.transform:  # 2. 만약 전처리(transform) 함수가 있다면
            image = self.transform(image)  # 3. 이미지를 변환(전처리)함
        return image, target  # 4. (전처리된) 이미지와 타깃 정보를 반환

    def __len__(self):
        return len(self.data)  # 전체 데이터(이미지) 개수를 반환

# %%
from torchvision import transforms
from torch.utils.data import DataLoader

def collator(batch):
    return tuple(zip(*batch))

transform = transforms.Compose([
    transforms.PILToTensor(),
    transforms.ConvertImageDtype(dtype=torch.float)
])
root = "/kaggle/input/pytorch-transformer/datasets/coco/"

train_dataset = COCODataset(root, train=True,transform=transform)
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, drop_last = True, 
          collate_fn = collator)
# Out:
# loading annotations into memory...
# Done (t=0.14s)
# creating index...
# index created!

# %%
test_dataset = COCODataset(root, train=False,transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=True, drop_last = True, 
          collate_fn = collator)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
from torchvision import models 
from torchvision import ops 
from torchvision.models.detection import rpn , FasterRCNN

# %%
backbone = models.vgg16(weights="VGG16_Weights.IMAGENET1K_V1").features
backbone.out_channels = 512
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 199MB/s]

# %%
anchor_generator = rpn.AnchorGenerator(
    sizes= ((32, 64, 128, 256, 512),),
    aspect_ratios = ((0.5, 1.0, 2.0),))

# %%
roi_pooler = ops.MultiScaleRoIAlign(
    featmap_names = ["0"],
    output_size=(7,7),
    sampling_ratio = 2
)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
model = FasterRCNN(
    backbone=backbone, 
    num_classes = 3,
    rpn_anchor_generator = anchor_generator,
    box_roi_pool  = roi_pooler
).to(device)

# %%
from torch import optim

params = [p for p in model.parameters() if p.requires_grad]
optimizer = optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
for epoch in range(5):
    cost = 0.0
    for idx, (images, targets)  in enumerate(train_dataloader):
        #image = image.to(device)
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum([loss for loss in loss_dict.values()])

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        cost += losses 
    lr_scheduler.step()
    cost = cost / len(train_dataloader)
    print(f"Epoch : {epoch + 1:4d}, Cost : {cost:.3f}")
# Out:
# Epoch :    1, Cost : 0.457
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35/3438396613.py in <cell line: 0>()
#       3     for idx, (images, targets)  in enumerate(train_dataloader):
#       4         #image = image.to(device)
# ----> 5         images = list(image.to(device) for image in images)
#       6         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#       7         loss_dict = model(images, targets)
#
# /tmp/ipykernel_35/3438396613.py in <genexpr>(.0)
#       3     for idx, (images, targets)  in enumerate(train_dataloader):
#       4         #image = image.to(device)
# ----> 5         images = list(image.to(device) for image in images)
#       6         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#       7         loss_dict = model(images, targets)
#
# KeyboardInterrupt:

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from torchvision.transforms.functional import to_pil_image

def draw_bbox(ax, box, text, color):
    # ax: matplotlib의 축(Axes) 객체 (이미지 위에 그릴 대상)
    # box: 바운딩 박스 좌표 [x1, y1, x2, y2] (좌상단, 우하단)
    # text: 박스에 표시할 라벨(클래스명 등)
    # color: 박스와 텍스트에 사용할 색상 (예: 'red', 'blue', '#00ff00' 등)

    ax.add_patch(
        plt.Rectangle(
            xy=(box[0], box[1]),                 # 사각형의 좌상단 좌표 (x1, y1)
            width=box[2] - box[0],               # 사각형의 너비 (x2 - x1)
            height=box[3] - box[1],              # 사각형의 높이 (y2 - y1)
            fill=False,                          # 내부를 채우지 않음 (테두리만 그림)
            edgecolor=color,                     # 테두리 색상 지정
            linewidth=2,                         # 테두리 두께
        )
    )
    # ↑ 바운딩 박스(사각형)를 이미지 위에 그림

    ax.annotate(
        text=text,                              # 표시할 텍스트(라벨)
        xy=(box[0] - 5, box[1] - 5),            # 텍스트를 박스 좌상단보다 약간 위/왼쪽에 위치시킴
        color=color,                            # 텍스트 색상
        weight="bold",

# %%
threshold = 0.5  # 예측 결과 중 신뢰도(score)가 이 값 이상인 것만 시각화 대상으로 필터링

categories = test_dataset.categories  # 클래스 id와 이름이 매핑된 딕셔너리 (예: {0: 'background', 1: 'person', ...})

with torch.no_grad():  # 평가(추론) 중에는 그래디언트 계산을 비활성화하여 메모리와 연산을 절약
    model.eval()  # 모델을 평가 모드로 전환 (드롭아웃, 배치정규화 등 비활성화)
    for images, targets in test_dataloader:  # 테스트 데이터로더에서 배치 단위로 이미지와 타깃 불러오기
        images = [image.to(device) for image in images]  # 각 이미지를 GPU/CPU(device)로 이동

        outputs = model(images)  # 모델에 이미지 리스트를 입력하여 예측 결과(바운딩박스, 라벨, 점수 등) 얻기

        # 첫 번째 이미지에 대한 예측 결과 추출
        boxes = outputs[0]["boxes"].to("cpu").numpy()    # 예측된 바운딩박스 좌표를 CPU로 옮기고 numpy 배열로 변환
        labels = outputs[0]["labels"].to("cpu").numpy()  # 예측된 클래스 라벨을 numpy 배열로 변환
        scores = outputs[0]["scores"].to("cpu").numpy()  # 각 바운딩박스의 신뢰도 점수를 numpy 배열로 변환

        # 신뢰도 점수가 threshold 이상인 결과만 필터링
        boxes = boxes[scores >= threshold].astype(np.int32)  # 좌표를 정수형으로 변환
        labels = labels[scores >= threshold]                 # 필터링된 라벨
        scores = scores[scores >= threshold]                 # 필터링된 점수

        # 시각화를 위한 matplotlib figure와 axis 생성
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(1, 1, 1)
        plt.imshow(to_pil_image(images[0]))  # 첫 번째 이미지를 PIL 이미지로 변환 후 출력

        # 예측된 바운딩박스와 라벨, 점수를 빨간색으로 그림
        for box, label, score in zip(boxes, labels, scores):
            draw_bbox(ax, box, f"{categories[label]} - {score:.4f}", "red")
            # draw_bbox: 바운딩 박스와 라벨(신뢰도 포함)을 빨간색으로 시각화

        # 실제 타깃(정답) 바운딩박스와 라벨을 파란색으로 그림
        tboxes = targets[0]["boxes"].numpy()   # 정답 바운딩박스 좌표
        tlabels = targets[0]["labels"].numpy() # 정답 라벨
        for box, label in zip(tboxes, tlabels):
            draw_bbox(ax, box, f"{categories[label]}", "blue")
            # draw_bbox: 정답 박스와 라벨을 파란색으로 시각화

        plt.show()  # 시각화 결과를 화면에 출력
